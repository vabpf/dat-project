# %%
from light_check import explore_directory_lightness
# Out:
# Bad pipe message: %s [b' 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Sa']
# Bad pipe message: %s [b'ri/537.36 Edg/138.0.0.0\r\nAccept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,ima', b'/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7\r\nAccept-Encoding: gzip, deflate, br,', b'std\r\nAccept-Language: en-US,en;']
# Bad pipe message: %s [b'0.9,en-GB;q=0.8\r\nPriority: u=0, i\r\nReferer: https://studio.firebase.google.com/\r\nSec-Ch-Ua: "Not)A;Brand";v="8",', b'Chromium";v="138", "Microsoft E']
# Bad pipe message: %s [b'e";v="138"\r\nSec-Ch-Ua-Arch: "x86"\r\nSec-Ch-Ua-Bitness: "64"\r\nSec-Ch-Ua-Form-Factors: "Desktop"\r\nSec-', b'-Ua-Full-Version: "138.0.3351.65"\r\nSec-Ch-Ua-Full-Version-List: "N']
# Bad pipe message: %s [b')A;Brand";v="8.0.0.0", "Chromium";v="138.0.7204.97", "Microsoft Edge";v="138.0.3351.65"\r\nSec-Ch-Ua-Mobile: ?0\r']
# ...

# %%
import os
files = []
for file in os.walk("/home/user/dat-project/data/images"):
    files.append(file)

len(files)
# Out:
# 226

# %%
a = explore_directory_lightness("/home/user/dat-project/data/images")
# Out:
# Exploring directory: /home/user/dat-project/data/images

# %%
count = 0
for light in a.keys():
    if a[light] > 210:
        count += 1

count
# Out:
# 0

# %%
import matplotlib.pyplot as plt

lighting_values = list(a.values())

# Create histogram
plt.figure(figsize=(8, 5))
plt.hist(lighting_values, bins=10, color='skyblue', edgecolor='black')
plt.title('Biểu đồ phân bố cường độ ánh sáng', weight='bold')
plt.xlabel('Cường độ ánh sáng')
plt.ylabel('Tần suất')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
1 - 7428/8459
# Out:
# 0.1218820191511999
