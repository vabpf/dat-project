# %%
# --- Configuration ---
DATASET_PATH = "/home/user/dat-project/data/images"
CUSTOM_ARCFACE_WEIGHTS_PATH = "/home/user/dat-project/models/weights/finetuned_arcface_2.h5"
OUTPUT_EMBEDDINGS_FILE = "/home/user/dat-project/data/embeddings"
MODEL_NAME= "ArcFace"

# DeepFace Model Configuration
# Note: DeepFace will use ArcFace as the base model structure for loading your weights.
# DeepFace supports multiple detector backends (e.g., 'opencv', 'ssd', 'dlib', 'mtcnn', 'retinaface', 'mediapipe', 'yunet')
DETECTOR_BACKEND = 'mtcnn' # MTCNN is generally robust, but you can try others
ENFORCE_FACE_DETECTION = False # If True, will raise an error if no face is detected. Set to False to skip images without faces.
